# %%
import random
import math
from typing import List, Dict, Any

# ==============================================================================
# 1. CORE DATA MODELS
# These classes represent the fundamental objects in your game.
# ==============================================================================


class Booster:
    """Represents a single type of booster with its properties."""

    def __init__(self, name: str, price: int, effectiveness: float):
        """
        Args:
            name (str): The booster's name (e.g., "Time Warp").
            price (int): Cost in coins to purchase.
            effectiveness (float): A value from 0.0 to 1.0 representing how much
                                   this booster reduces level duration. 0.2 means 20% faster.
        """
        self.name = name
        self.price = price
        self.effectiveness = effectiveness

    def __repr__(self) -> str:
        return f"Booster(name='{self.name}')"


class Level:
    """Represents a single level in the game."""

    def __init__(self, level_id: int, base_duration: int, difficulty: float, rewards: Dict[str, Any]):
        """
        Args:
            level_id (int): The level number.
            base_duration (int): Expected time in seconds to complete for an average player.
            difficulty (float): A value from 0.0 to 1.0 indicating the level's challenge.
            rewards (Dict[str, Any]): Resources given upon completion.
                                      Example: {'coins': 50, 'boosters': {'Time Warp': 1}}
        """
        self.level_id = level_id
        self.base_duration = base_duration
        self.difficulty = difficulty
        self.rewards = rewards

    def __repr__(self) -> str:
        return f"Level(id={self.level_id}, difficulty={self.difficulty:.2f})"


class Player:
    """Represents a player archetype with their stats and inventory."""

    def __init__(self, player_id: str, skill_potential: float, booster_tendency: float, daily_playtime_budget: int, initial_inventory: Dict[str, Any]):
        """
        Args:
            player_id (str): A unique name for this player archetype (e.g., "Frugal_Expert").
            skill_potential (float): Innate skill (0.0 to 1.0). High skill negates difficulty.
            booster_tendency (float): Baseline willingness to use boosters (0.0 to 1.0).
            daily_playtime_budget (int): Total seconds the player will play in a day.
            initial_inventory (Dict[str, Any]): Starting resources.
        """
        self.player_id = player_id
        self.skill_potential = skill_potential
        self.booster_tendency = booster_tendency

        self.initial_playtime = daily_playtime_budget
        self.daily_playtime_budget = daily_playtime_budget

        # Deep copy inventory to prevent archetypes from sharing the same object
        self.inventory = {
            'coins': initial_inventory.get('coins', 0),
            'boosters': initial_inventory.get('boosters', {}).copy()
        }
        self.current_level = 0
        self.days_to_reach_target = None

    def get_total_boosters(self) -> int:
        """Returns the total count of all boosters in inventory."""
        return sum(self.inventory['boosters'].values())

    def has_boosters(self) -> bool:
        """Checks if the player has any boosters."""
        return self.get_total_boosters() > 0

    def consume_boosters(self, quantity: int, booster_definitions: Dict[str, Booster]):
        """
        Consumes a specified quantity of boosters from inventory.
        Picks randomly from available boosters. Returns the total effectiveness.
        """
        total_effectiveness = 0.0
        consumed_count = 0

        # Get a list of boosters the player actually owns
        owned_boosters = [
            b for b, count in self.inventory['boosters'].items() if count > 0]
        random.shuffle(owned_boosters)

        for booster_name in owned_boosters:
            if consumed_count >= quantity:
                break

            # Consume one of this booster
            self.inventory['boosters'][booster_name] -= 1
            total_effectiveness += booster_definitions[booster_name].effectiveness
            consumed_count += 1

        return total_effectiveness

    def add_rewards(self, rewards: Dict[str, Any]):
        """Adds level rewards to the player's inventory."""
        self.inventory['coins'] += rewards.get('coins', 0)
        booster_rewards = rewards.get('boosters', {})
        for name, count in booster_rewards.items():
            self.inventory['boosters'][name] = self.inventory['boosters'].get(
                name, 0) + count

    def reset_daily_playtime(self):
        """Resets the daily playtime budget to its initial value."""
        self.daily_playtime_budget = self.initial_playtime

    def __repr__(self) -> str:
        return f"Player(id='{self.player_id}', level={self.current_level}, coins={self.inventory['coins']}, boosters={self.get_total_boosters()})"

# ==============================================================================
# 2. THE SIMULATOR ENGINE
# This class orchestrates the entire simulation process.
# ==============================================================================


class GameSimulator:
    """Runs the game simulation for a set of players and levels."""

    # Tunable simulation parameters
    MAX_BOOSTERS_PER_LEVEL = 3

    def __init__(self, players: List[Player], levels: List[Level], boosters: List[Booster]):
        self.players = players
        self.levels = sorted(levels, key=lambda lvl: lvl.level_id)
        self.booster_definitions = {b.name: b for b in boosters}
        self.log = []

    def _simulate_level_attempt(self, player: Player, level: Level):
        """Core logic for a single player attempting a single level."""

        # --- a. Calculate Struggle ---
        struggle_score = max(0, level.difficulty - player.skill_potential)

        # --- b. Decide IF boosters will be used ---
        prob_to_use = player.booster_tendency + \
            (struggle_score * (1 - player.booster_tendency))

        boosters_to_use = 0
        booster_effectiveness = 0.0

        if player.has_boosters() and random.random() < prob_to_use:
            # --- c. Decide HOW MANY boosters will be used ---
            scores = []
            for k in range(1, self.MAX_BOOSTERS_PER_LEVEL + 1):
                score = (1 + struggle_score) ** k
                scores.append(score)

            # Weighted random choice to select quantity
            chosen_quantity = random.choices(
                population=range(1, self.MAX_BOOSTERS_PER_LEVEL + 1),
                weights=scores,
                k=1
            )[0]

            # Ensure player doesn't use more boosters than they own
            boosters_to_use = min(chosen_quantity, player.get_total_boosters())

        # --- d. Calculate Final Playtime ---
        base_time_cost = level.base_duration * (1 + struggle_score)

        if boosters_to_use > 0:
            booster_effectiveness = player.consume_boosters(
                boosters_to_use, self.booster_definitions)

        final_playtime = base_time_cost * (1 - booster_effectiveness)
        # Round up to nearest second
        final_playtime = math.ceil(final_playtime)

        return {
            "playtime": final_playtime,
            "boosters_used": boosters_to_use,
            "struggle_score": struggle_score
        }

    def _run_simulation_for_days(self, days_to_simulate: int):
        """Internal method to run simulation for a fixed number of days."""
        for day in range(1, days_to_simulate + 1):
            print(f"\n==================== DAY {day} ====================")
            for player in self.players:
                player.reset_daily_playtime()
                # ... rest of daily simulation logic ...
                # This is the same loop as before
                print(f"\n[SIMULATING] Player: {player.player_id}")
                print(
                    f"  > Start of Day State: Level {player.current_level}, Playtime Budget: {player.daily_playtime_budget}s, Coins: {player.inventory['coins']}, Boosters: {player.get_total_boosters()}")

                while player.daily_playtime_budget > 0 and player.current_level < len(self.levels):
                    current_level_obj = self.levels[player.current_level]
                    attempt_result = self._simulate_level_attempt(
                        player, current_level_obj)
                    playtime_cost = attempt_result["playtime"]

                    if player.daily_playtime_budget < playtime_cost:
                        break

                    player.daily_playtime_budget -= playtime_cost
                    player.add_rewards(current_level_obj.rewards)
                    player.current_level += 1

                    # ... logging ...
                    log_entry = {"day": day, "player_id": player.player_id, "level_id": current_level_obj.level_id, "struggle_score": f"{attempt_result['struggle_score']:.2f}", "boosters_used": attempt_result[
                        'boosters_used'], "playtime_cost": playtime_cost, "playtime_left": player.daily_playtime_budget, "final_coins": player.inventory['coins'], "final_boosters": player.get_total_boosters()}
                    self.log.append(log_entry)

                print(
                    f"  > End of Day State: Reached Level {player.current_level}, Playtime Left: {player.daily_playtime_budget}s, Coins: {player.inventory['coins']}, Boosters: {player.get_total_boosters()}")

    def _run_simulation_to_level(self, target_level: int):
        """Internal method to run simulation until a target level is reached."""
        day = 0
        while any(p.current_level < target_level for p in self.players):
            day += 1
            print(f"\n==================== DAY {day} ====================")

            if all(p.current_level >= len(self.levels) for p in self.players if p.current_level < target_level):
                print(
                    "\n[STOP] All players have run out of available levels before reaching the target.")
                break

            for player in self.players:
                if player.current_level >= target_level:
                    continue

                player.reset_daily_playtime()
                print(
                    f"\n[SIMULATING] Player: {player.player_id} (Target: Lv.{target_level})")

                while player.daily_playtime_budget > 0 and player.current_level < target_level and player.current_level < len(self.levels):
                    current_level_obj = self.levels[player.current_level]
                    attempt_result = self._simulate_level_attempt(
                        player, current_level_obj)
                    playtime_cost = attempt_result["playtime"]

                    if player.daily_playtime_budget < playtime_cost:
                        break

                    player.daily_playtime_budget -= playtime_cost
                    player.add_rewards(current_level_obj.rewards)
                    player.current_level += 1

                    # Record the day the player reached the target level
                    if player.current_level == target_level and player.days_to_reach_target is None:
                        player.days_to_reach_target = day

                    # ... logging ...
                    log_entry = {"day": day, "player_id": player.player_id, "level_id": current_level_obj.level_id, "struggle_score": f"{attempt_result['struggle_score']:.2f}", "boosters_used": attempt_result[
                        'boosters_used'], "playtime_cost": playtime_cost, "playtime_left": player.daily_playtime_budget, "final_coins": player.inventory['coins'], "final_boosters": player.get_total_boosters()}
                    self.log.append(log_entry)

    def run_simulation(self, target_days: int = None, target_level: int = None):
        """Runs the full simulation with a specified target."""
        if (target_days and target_level) or (not target_days and not target_level):
            raise ValueError(
                "Please specify either 'target_days' OR 'target_level'.")

        self.log = []
        print("--- Starting Game Simulation ---")

        if target_days:
            self._run_simulation_for_days(target_days)
        elif target_level:
            self._run_simulation_to_level(target_level)

        print("\n--- Simulation Complete ---")
        return self.log

    def print_summary(self):
        """Prints a formatted summary of the simulation log."""
        print("\n--- Simulation Log Summary ---")
        if not self.log:
            print("No logs recorded.")
            return

        for entry in self.log:
            print(
                f"--- Day {entry['day']} | Player: {entry['player_id']} | Level Cleared: {entry['level_id']} ---")
            print(f"  - Struggle Score: {entry['struggle_score']}")
            print(f"  - Boosters Used:  {entry['boosters_used']}")
            print(f"  - Time Cost:      {entry['playtime_cost']}s")
            print(f"  - State After Level:")
            print(f"    - Playtime Left: {entry['playtime_left']}s")
            print(f"    - Final Coins:   {entry['final_coins']}")
            print(f"    - Final Boosters: {entry['final_boosters']}")
            print("-" * 45)

    def print_player_information_summary(self):
        """Prints a detailed summary of each player's final state and stats."""
        print("\n--- Final Player Information Summary ---")
        for player in self.players:
            print(f"Player: {player.player_id}")
            print(f"  - Archetype Stats:")
            print(f"    - Skill Potential: {player.skill_potential}")
            print(f"    - Booster Tendency: {player.booster_tendency}")
            print(f"  - Final State:")
            print(f"    - Reached Level: {player.current_level}")
            if player.days_to_reach_target:
                print(
                    f"    - Days to Reach Target: {player.days_to_reach_target}")
            print(f"    - Final Coins:   {player.inventory['coins']}")
            print(f"    - Final Boosters:")
            if not player.inventory['boosters'] or all(v == 0 for v in player.inventory['boosters'].values()):
                print("      - None")
            else:
                for name, count in player.inventory['boosters'].items():
                    if count > 0:
                        print(f"      - {name}: {count}")
            print("-" * 30)


# ==============================================================================
# 3. SIMULATION SETUP & EXECUTION
# This is where you define your game's data and run the simulator.
# ==============================================================================

if __name__ == "__main__":
    # --- Define Boosters ---
    booster_list = [
        Booster(name="Speedy Time", price=50,
                effectiveness=0.20),  # 20% time reduction
        Booster(name="Mega Clear", price=75,
                effectiveness=0.35)    # 35% time reduction
    ]

    # --- Define Levels (Create a progression curve) ---
    level_list = []
    # Create 100 levels for a longer simulation
    for i in range(1, 101):
        rewards = {'coins': 10 + i * 2}
        if i % 4 == 0:
            rewards['boosters'] = {random.choice(booster_list).name: 1}

        level_list.append(Level(
            level_id=i,
            base_duration=60 + i * 5,
            # Difficulty ramps from ~0.1 to ~0.9
            difficulty=0.1 + (i / 100) * 0.8,
            rewards=rewards
        ))

    default_init_inventory = {
        'coins': 100,
        'boosters': {
            'Speedy Time': 3,
            'Mega Clear': 1
        }
    }

    # --- Define Player Archetypes ---
    player_archetypes = [
        Player(
            player_id="Frugal_Expert",
            skill_potential=0.8,
            booster_tendency=0.1,
            daily_playtime_budget=1800,  # 30 minutes
            initial_inventory=default_init_inventory.copy()
        ),
        Player(
            player_id="Average_Joe",
            skill_potential=0.5,
            booster_tendency=0.5,
            daily_playtime_budget=1800,  # 30 minutes
            # initial_inventory={'coins': 100, 'boosters': {'Speedy Time': 3, 'Mega Clear': 1}}
            initial_inventory=default_init_inventory.copy()
        ),
        Player(
            player_id="Rich_Spender",
            skill_potential=0.2,
            booster_tendency=0.9,
            daily_playtime_budget=1800,  # 30 minutes
            initial_inventory=default_init_inventory.copy()
        )
    ]

    # --- Run the Simulation to answer the question about Level 54 ---
    # NOTE: The simulation will stop once all players have PASSED level 53 (i.e., reached level 54)
    TARGET_LEVEL = 54
    simulator = GameSimulator(player_archetypes, level_list, booster_list)
    simulation_log = simulator.run_simulation(target_level=TARGET_LEVEL)

    # --- Print the Results ---
    # The full log is too long, so we will just print the final summary
    # simulator.print_summary() # Uncomment if you want to see the full level-by-level log

    simulator.print_player_information_summary()
    simulator.print_summary()
# Out:
# --- Starting Game Simulation ---
#
# ==================== DAY 1 ====================
#
# [SIMULATING] Player: Frugal_Expert (Target: Lv.54)
#
# [SIMULATING] Player: Average_Joe (Target: Lv.54)
#
# [SIMULATING] Player: Rich_Spender (Target: Lv.54)
#
# ==================== DAY 2 ====================
#
# [SIMULATING] Player: Frugal_Expert (Target: Lv.54)
#
# [SIMULATING] Player: Average_Joe (Target: Lv.54)
#
# [SIMULATING] Player: Rich_Spender (Target: Lv.54)
#
# ==================== DAY 3 ====================
#
# [SIMULATING] Player: Frugal_Expert (Target: Lv.54)
#
# [SIMULATING] Player: Average_Joe (Target: Lv.54)
#
# [SIMULATING] Player: Rich_Spender (Target: Lv.54)
#
# ==================== DAY 4 ====================
#
# [SIMULATING] Player: Frugal_Expert (Target: Lv.54)
#
# [SIMULATING] Player: Average_Joe (Target: Lv.54)
#
# [SIMULATING] Player: Rich_Spender (Target: Lv.54)
#
# ==================== DAY 5 ====================
#
# [SIMULATING] Player: Frugal_Expert (Target: Lv.54)
#
# [SIMULATING] Player: Average_Joe (Target: Lv.54)
#
# [SIMULATING] Player: Rich_Spender (Target: Lv.54)
#
# ==================== DAY 6 ====================
#
# [SIMULATING] Player: Frugal_Expert (Target: Lv.54)
#
# [SIMULATING] Player: Average_Joe (Target: Lv.54)
#
# [SIMULATING] Player: Rich_Spender (Target: Lv.54)
#
# ==================== DAY 7 ====================
#
# [SIMULATING] Player: Frugal_Expert (Target: Lv.54)
#
# [SIMULATING] Player: Rich_Spender (Target: Lv.54)
#
# --- Simulation Complete ---
#
# --- Final Player Information Summary ---
# Player: Frugal_Expert
#   - Archetype Stats:
#     - Skill Potential: 0.8
#     - Booster Tendency: 0.1
#   - Final State:
#     - Reached Level: 54
#     - Days to Reach Target: 7
#     - Final Coins:   3610
#     - Final Boosters:
#       - Speedy Time: 6
#       - Mega Clear: 1
# ------------------------------
# Player: Average_Joe
#   - Archetype Stats:
#     - Skill Potential: 0.5
#     - Booster Tendency: 0.5
#   - Final State:
#     - Reached Level: 54
#     - Days to Reach Target: 6
#     - Final Coins:   3610
#     - Final Boosters:
#       - Speedy Time: 1
# ------------------------------
# Player: Rich_Spender
#   - Archetype Stats:
#     - Skill Potential: 0.2
#     - Booster Tendency: 0.9
#   - Final State:
#     - Reached Level: 54
#     - Days to Reach Target: 7
#     - Final Coins:   3610
#     - Final Boosters:
#       - None
# ------------------------------
#
# --- Simulation Log Summary ---
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 1 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  3
#   - Time Cost:      30s
#   - State After Level:
#     - Playtime Left: 1770s
#     - Final Coins:   112
#     - Final Boosters: 2
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 2 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      70s
#   - State After Level:
#     - Playtime Left: 1700s
#     - Final Coins:   126
#     - Final Boosters: 2
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 3 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      75s
#   - State After Level:
#     - Playtime Left: 1625s
#     - Final Coins:   142
#     - Final Boosters: 2
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 4 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      80s
#   - State After Level:
#     - Playtime Left: 1545s
#     - Final Coins:   160
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 5 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      85s
#   - State After Level:
#     - Playtime Left: 1460s
#     - Final Coins:   180
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 6 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      90s
#   - State After Level:
#     - Playtime Left: 1370s
#     - Final Coins:   202
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 7 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      95s
#   - State After Level:
#     - Playtime Left: 1275s
#     - Final Coins:   226
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 8 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      100s
#   - State After Level:
#     - Playtime Left: 1175s
#     - Final Coins:   252
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 9 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      105s
#   - State After Level:
#     - Playtime Left: 1070s
#     - Final Coins:   280
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 10 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      110s
#   - State After Level:
#     - Playtime Left: 960s
#     - Final Coins:   310
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 11 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  2
#   - Time Cost:      52s
#   - State After Level:
#     - Playtime Left: 908s
#     - Final Coins:   342
#     - Final Boosters: 2
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 12 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      120s
#   - State After Level:
#     - Playtime Left: 788s
#     - Final Coins:   376
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 13 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      125s
#   - State After Level:
#     - Playtime Left: 663s
#     - Final Coins:   412
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 14 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      130s
#   - State After Level:
#     - Playtime Left: 533s
#     - Final Coins:   450
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 15 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      135s
#   - State After Level:
#     - Playtime Left: 398s
#     - Final Coins:   490
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 16 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      140s
#   - State After Level:
#     - Playtime Left: 258s
#     - Final Coins:   532
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 1 | Player: Frugal_Expert | Level Cleared: 17 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      145s
#   - State After Level:
#     - Playtime Left: 113s
#     - Final Coins:   576
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 1 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  2
#   - Time Cost:      30s
#   - State After Level:
#     - Playtime Left: 1770s
#     - Final Coins:   112
#     - Final Boosters: 2
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 2 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  2
#   - Time Cost:      56s
#   - State After Level:
#     - Playtime Left: 1714s
#     - Final Coins:   126
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 3 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      60s
#   - State After Level:
#     - Playtime Left: 1654s
#     - Final Coins:   142
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 4 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      80s
#   - State After Level:
#     - Playtime Left: 1574s
#     - Final Coins:   160
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 5 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      56s
#   - State After Level:
#     - Playtime Left: 1518s
#     - Final Coins:   180
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 6 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      90s
#   - State After Level:
#     - Playtime Left: 1428s
#     - Final Coins:   202
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 7 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      95s
#   - State After Level:
#     - Playtime Left: 1333s
#     - Final Coins:   226
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 8 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      100s
#   - State After Level:
#     - Playtime Left: 1233s
#     - Final Coins:   252
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 9 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      84s
#   - State After Level:
#     - Playtime Left: 1149s
#     - Final Coins:   280
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 10 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      110s
#   - State After Level:
#     - Playtime Left: 1039s
#     - Final Coins:   310
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 11 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      115s
#   - State After Level:
#     - Playtime Left: 924s
#     - Final Coins:   342
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 12 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      120s
#   - State After Level:
#     - Playtime Left: 804s
#     - Final Coins:   376
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 13 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      125s
#   - State After Level:
#     - Playtime Left: 679s
#     - Final Coins:   412
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 14 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      130s
#   - State After Level:
#     - Playtime Left: 549s
#     - Final Coins:   450
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 15 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      88s
#   - State After Level:
#     - Playtime Left: 461s
#     - Final Coins:   490
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 16 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      140s
#   - State After Level:
#     - Playtime Left: 321s
#     - Final Coins:   532
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 17 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      116s
#   - State After Level:
#     - Playtime Left: 205s
#     - Final Coins:   576
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Average_Joe | Level Cleared: 18 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      150s
#   - State After Level:
#     - Playtime Left: 55s
#     - Final Coins:   622
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 1 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  3
#   - Time Cost:      30s
#   - State After Level:
#     - Playtime Left: 1770s
#     - Final Coins:   112
#     - Final Boosters: 2
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 2 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  2
#   - Time Cost:      56s
#   - State After Level:
#     - Playtime Left: 1714s
#     - Final Coins:   126
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 3 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      60s
#   - State After Level:
#     - Playtime Left: 1654s
#     - Final Coins:   142
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 4 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      80s
#   - State After Level:
#     - Playtime Left: 1574s
#     - Final Coins:   160
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 5 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      56s
#   - State After Level:
#     - Playtime Left: 1518s
#     - Final Coins:   180
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 6 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      90s
#   - State After Level:
#     - Playtime Left: 1428s
#     - Final Coins:   202
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 7 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      95s
#   - State After Level:
#     - Playtime Left: 1333s
#     - Final Coins:   226
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 8 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      100s
#   - State After Level:
#     - Playtime Left: 1233s
#     - Final Coins:   252
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 9 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      84s
#   - State After Level:
#     - Playtime Left: 1149s
#     - Final Coins:   280
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 10 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      110s
#   - State After Level:
#     - Playtime Left: 1039s
#     - Final Coins:   310
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 11 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      115s
#   - State After Level:
#     - Playtime Left: 924s
#     - Final Coins:   342
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 12 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      120s
#   - State After Level:
#     - Playtime Left: 804s
#     - Final Coins:   376
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 13 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      82s
#   - State After Level:
#     - Playtime Left: 722s
#     - Final Coins:   412
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 14 ---
#   - Struggle Score: 0.01
#   - Boosters Used:  0
#   - Time Cost:      132s
#   - State After Level:
#     - Playtime Left: 590s
#     - Final Coins:   450
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 15 ---
#   - Struggle Score: 0.02
#   - Boosters Used:  0
#   - Time Cost:      138s
#   - State After Level:
#     - Playtime Left: 452s
#     - Final Coins:   490
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 16 ---
#   - Struggle Score: 0.03
#   - Boosters Used:  0
#   - Time Cost:      144s
#   - State After Level:
#     - Playtime Left: 308s
#     - Final Coins:   532
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 17 ---
#   - Struggle Score: 0.04
#   - Boosters Used:  0
#   - Time Cost:      151s
#   - State After Level:
#     - Playtime Left: 157s
#     - Final Coins:   576
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 1 | Player: Rich_Spender | Level Cleared: 18 ---
#   - Struggle Score: 0.04
#   - Boosters Used:  1
#   - Time Cost:      126s
#   - State After Level:
#     - Playtime Left: 31s
#     - Final Coins:   622
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 18 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      150s
#   - State After Level:
#     - Playtime Left: 1650s
#     - Final Coins:   622
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 19 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      155s
#   - State After Level:
#     - Playtime Left: 1495s
#     - Final Coins:   670
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 20 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      104s
#   - State After Level:
#     - Playtime Left: 1391s
#     - Final Coins:   720
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 21 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      165s
#   - State After Level:
#     - Playtime Left: 1226s
#     - Final Coins:   772
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 22 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      170s
#   - State After Level:
#     - Playtime Left: 1056s
#     - Final Coins:   826
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 23 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      175s
#   - State After Level:
#     - Playtime Left: 881s
#     - Final Coins:   882
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 24 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      180s
#   - State After Level:
#     - Playtime Left: 701s
#     - Final Coins:   940
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 25 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      148s
#   - State After Level:
#     - Playtime Left: 553s
#     - Final Coins:   1000
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 26 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      190s
#   - State After Level:
#     - Playtime Left: 363s
#     - Final Coins:   1062
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 2 | Player: Frugal_Expert | Level Cleared: 27 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      195s
#   - State After Level:
#     - Playtime Left: 168s
#     - Final Coins:   1126
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 19 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      155s
#   - State After Level:
#     - Playtime Left: 1645s
#     - Final Coins:   670
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 20 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      160s
#   - State After Level:
#     - Playtime Left: 1485s
#     - Final Coins:   720
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 21 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      108s
#   - State After Level:
#     - Playtime Left: 1377s
#     - Final Coins:   772
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 22 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      170s
#   - State After Level:
#     - Playtime Left: 1207s
#     - Final Coins:   826
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 23 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      175s
#   - State After Level:
#     - Playtime Left: 1032s
#     - Final Coins:   882
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 24 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      180s
#   - State After Level:
#     - Playtime Left: 852s
#     - Final Coins:   940
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 25 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      185s
#   - State After Level:
#     - Playtime Left: 667s
#     - Final Coins:   1000
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 26 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      124s
#   - State After Level:
#     - Playtime Left: 543s
#     - Final Coins:   1062
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 27 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      195s
#   - State After Level:
#     - Playtime Left: 348s
#     - Final Coins:   1126
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Average_Joe | Level Cleared: 28 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      200s
#   - State After Level:
#     - Playtime Left: 148s
#     - Final Coins:   1192
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 2 | Player: Rich_Spender | Level Cleared: 19 ---
#   - Struggle Score: 0.05
#   - Boosters Used:  0
#   - Time Cost:      164s
#   - State After Level:
#     - Playtime Left: 1636s
#     - Final Coins:   670
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Rich_Spender | Level Cleared: 20 ---
#   - Struggle Score: 0.06
#   - Boosters Used:  0
#   - Time Cost:      170s
#   - State After Level:
#     - Playtime Left: 1466s
#     - Final Coins:   720
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 2 | Player: Rich_Spender | Level Cleared: 21 ---
#   - Struggle Score: 0.07
#   - Boosters Used:  1
#   - Time Cost:      115s
#   - State After Level:
#     - Playtime Left: 1351s
#     - Final Coins:   772
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Rich_Spender | Level Cleared: 22 ---
#   - Struggle Score: 0.08
#   - Boosters Used:  0
#   - Time Cost:      183s
#   - State After Level:
#     - Playtime Left: 1168s
#     - Final Coins:   826
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Rich_Spender | Level Cleared: 23 ---
#   - Struggle Score: 0.08
#   - Boosters Used:  0
#   - Time Cost:      190s
#   - State After Level:
#     - Playtime Left: 978s
#     - Final Coins:   882
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Rich_Spender | Level Cleared: 24 ---
#   - Struggle Score: 0.09
#   - Boosters Used:  0
#   - Time Cost:      197s
#   - State After Level:
#     - Playtime Left: 781s
#     - Final Coins:   940
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 2 | Player: Rich_Spender | Level Cleared: 25 ---
#   - Struggle Score: 0.10
#   - Boosters Used:  1
#   - Time Cost:      133s
#   - State After Level:
#     - Playtime Left: 648s
#     - Final Coins:   1000
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Rich_Spender | Level Cleared: 26 ---
#   - Struggle Score: 0.11
#   - Boosters Used:  0
#   - Time Cost:      211s
#   - State After Level:
#     - Playtime Left: 437s
#     - Final Coins:   1062
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 2 | Player: Rich_Spender | Level Cleared: 27 ---
#   - Struggle Score: 0.12
#   - Boosters Used:  0
#   - Time Cost:      218s
#   - State After Level:
#     - Playtime Left: 219s
#     - Final Coins:   1126
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Frugal_Expert | Level Cleared: 28 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      200s
#   - State After Level:
#     - Playtime Left: 1600s
#     - Final Coins:   1192
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 3 | Player: Frugal_Expert | Level Cleared: 29 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      205s
#   - State After Level:
#     - Playtime Left: 1395s
#     - Final Coins:   1260
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 3 | Player: Frugal_Expert | Level Cleared: 30 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  3
#   - Time Cost:      95s
#   - State After Level:
#     - Playtime Left: 1300s
#     - Final Coins:   1330
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 3 | Player: Frugal_Expert | Level Cleared: 31 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      215s
#   - State After Level:
#     - Playtime Left: 1085s
#     - Final Coins:   1402
#     - Final Boosters: 3
# ---------------------------------------------
# --- Day 3 | Player: Frugal_Expert | Level Cleared: 32 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      220s
#   - State After Level:
#     - Playtime Left: 865s
#     - Final Coins:   1476
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 3 | Player: Frugal_Expert | Level Cleared: 33 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      225s
#   - State After Level:
#     - Playtime Left: 640s
#     - Final Coins:   1552
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 3 | Player: Frugal_Expert | Level Cleared: 34 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      230s
#   - State After Level:
#     - Playtime Left: 410s
#     - Final Coins:   1630
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 3 | Player: Frugal_Expert | Level Cleared: 35 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      235s
#   - State After Level:
#     - Playtime Left: 175s
#     - Final Coins:   1710
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 3 | Player: Average_Joe | Level Cleared: 29 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      205s
#   - State After Level:
#     - Playtime Left: 1595s
#     - Final Coins:   1260
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Average_Joe | Level Cleared: 30 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      210s
#   - State After Level:
#     - Playtime Left: 1385s
#     - Final Coins:   1330
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Average_Joe | Level Cleared: 31 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      215s
#   - State After Level:
#     - Playtime Left: 1170s
#     - Final Coins:   1402
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Average_Joe | Level Cleared: 32 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      220s
#   - State After Level:
#     - Playtime Left: 950s
#     - Final Coins:   1476
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 3 | Player: Average_Joe | Level Cleared: 33 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      180s
#   - State After Level:
#     - Playtime Left: 770s
#     - Final Coins:   1552
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Average_Joe | Level Cleared: 34 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      230s
#   - State After Level:
#     - Playtime Left: 540s
#     - Final Coins:   1630
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Average_Joe | Level Cleared: 35 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      235s
#   - State After Level:
#     - Playtime Left: 305s
#     - Final Coins:   1710
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Average_Joe | Level Cleared: 36 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      240s
#   - State After Level:
#     - Playtime Left: 65s
#     - Final Coins:   1792
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 3 | Player: Rich_Spender | Level Cleared: 28 ---
#   - Struggle Score: 0.12
#   - Boosters Used:  0
#   - Time Cost:      225s
#   - State After Level:
#     - Playtime Left: 1575s
#     - Final Coins:   1192
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 3 | Player: Rich_Spender | Level Cleared: 29 ---
#   - Struggle Score: 0.13
#   - Boosters Used:  1
#   - Time Cost:      186s
#   - State After Level:
#     - Playtime Left: 1389s
#     - Final Coins:   1260
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Rich_Spender | Level Cleared: 30 ---
#   - Struggle Score: 0.14
#   - Boosters Used:  0
#   - Time Cost:      240s
#   - State After Level:
#     - Playtime Left: 1149s
#     - Final Coins:   1330
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Rich_Spender | Level Cleared: 31 ---
#   - Struggle Score: 0.15
#   - Boosters Used:  0
#   - Time Cost:      247s
#   - State After Level:
#     - Playtime Left: 902s
#     - Final Coins:   1402
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Rich_Spender | Level Cleared: 32 ---
#   - Struggle Score: 0.16
#   - Boosters Used:  0
#   - Time Cost:      255s
#   - State After Level:
#     - Playtime Left: 647s
#     - Final Coins:   1476
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 3 | Player: Rich_Spender | Level Cleared: 33 ---
#   - Struggle Score: 0.16
#   - Boosters Used:  1
#   - Time Cost:      210s
#   - State After Level:
#     - Playtime Left: 437s
#     - Final Coins:   1552
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 3 | Player: Rich_Spender | Level Cleared: 34 ---
#   - Struggle Score: 0.17
#   - Boosters Used:  0
#   - Time Cost:      270s
#   - State After Level:
#     - Playtime Left: 167s
#     - Final Coins:   1630
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Frugal_Expert | Level Cleared: 36 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      240s
#   - State After Level:
#     - Playtime Left: 1560s
#     - Final Coins:   1792
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 4 | Player: Frugal_Expert | Level Cleared: 37 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      245s
#   - State After Level:
#     - Playtime Left: 1315s
#     - Final Coins:   1876
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 4 | Player: Frugal_Expert | Level Cleared: 38 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      250s
#   - State After Level:
#     - Playtime Left: 1065s
#     - Final Coins:   1962
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 4 | Player: Frugal_Expert | Level Cleared: 39 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      255s
#   - State After Level:
#     - Playtime Left: 810s
#     - Final Coins:   2050
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 4 | Player: Frugal_Expert | Level Cleared: 40 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  2
#   - Time Cost:      117s
#   - State After Level:
#     - Playtime Left: 693s
#     - Final Coins:   2140
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 4 | Player: Frugal_Expert | Level Cleared: 41 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      265s
#   - State After Level:
#     - Playtime Left: 428s
#     - Final Coins:   2232
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 4 | Player: Frugal_Expert | Level Cleared: 42 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      270s
#   - State After Level:
#     - Playtime Left: 158s
#     - Final Coins:   2326
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 4 | Player: Average_Joe | Level Cleared: 37 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      245s
#   - State After Level:
#     - Playtime Left: 1555s
#     - Final Coins:   1876
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Average_Joe | Level Cleared: 38 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      250s
#   - State After Level:
#     - Playtime Left: 1305s
#     - Final Coins:   1962
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Average_Joe | Level Cleared: 39 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      255s
#   - State After Level:
#     - Playtime Left: 1050s
#     - Final Coins:   2050
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Average_Joe | Level Cleared: 40 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      260s
#   - State After Level:
#     - Playtime Left: 790s
#     - Final Coins:   2140
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 4 | Player: Average_Joe | Level Cleared: 41 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      265s
#   - State After Level:
#     - Playtime Left: 525s
#     - Final Coins:   2232
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 4 | Player: Average_Joe | Level Cleared: 42 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      216s
#   - State After Level:
#     - Playtime Left: 309s
#     - Final Coins:   2326
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Average_Joe | Level Cleared: 43 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      275s
#   - State After Level:
#     - Playtime Left: 34s
#     - Final Coins:   2422
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Rich_Spender | Level Cleared: 35 ---
#   - Struggle Score: 0.18
#   - Boosters Used:  0
#   - Time Cost:      278s
#   - State After Level:
#     - Playtime Left: 1522s
#     - Final Coins:   1710
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Rich_Spender | Level Cleared: 36 ---
#   - Struggle Score: 0.19
#   - Boosters Used:  0
#   - Time Cost:      286s
#   - State After Level:
#     - Playtime Left: 1236s
#     - Final Coins:   1792
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 4 | Player: Rich_Spender | Level Cleared: 37 ---
#   - Struggle Score: 0.20
#   - Boosters Used:  1
#   - Time Cost:      235s
#   - State After Level:
#     - Playtime Left: 1001s
#     - Final Coins:   1876
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Rich_Spender | Level Cleared: 38 ---
#   - Struggle Score: 0.20
#   - Boosters Used:  0
#   - Time Cost:      301s
#   - State After Level:
#     - Playtime Left: 700s
#     - Final Coins:   1962
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Rich_Spender | Level Cleared: 39 ---
#   - Struggle Score: 0.21
#   - Boosters Used:  0
#   - Time Cost:      310s
#   - State After Level:
#     - Playtime Left: 390s
#     - Final Coins:   2050
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 4 | Player: Rich_Spender | Level Cleared: 40 ---
#   - Struggle Score: 0.22
#   - Boosters Used:  0
#   - Time Cost:      318s
#   - State After Level:
#     - Playtime Left: 72s
#     - Final Coins:   2140
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 5 | Player: Frugal_Expert | Level Cleared: 43 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      275s
#   - State After Level:
#     - Playtime Left: 1525s
#     - Final Coins:   2422
#     - Final Boosters: 4
# ---------------------------------------------
# --- Day 5 | Player: Frugal_Expert | Level Cleared: 44 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      280s
#   - State After Level:
#     - Playtime Left: 1245s
#     - Final Coins:   2520
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 5 | Player: Frugal_Expert | Level Cleared: 45 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      285s
#   - State After Level:
#     - Playtime Left: 960s
#     - Final Coins:   2620
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 5 | Player: Frugal_Expert | Level Cleared: 46 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      290s
#   - State After Level:
#     - Playtime Left: 670s
#     - Final Coins:   2722
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 5 | Player: Frugal_Expert | Level Cleared: 47 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      295s
#   - State After Level:
#     - Playtime Left: 375s
#     - Final Coins:   2826
#     - Final Boosters: 5
# ---------------------------------------------
# --- Day 5 | Player: Frugal_Expert | Level Cleared: 48 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      300s
#   - State After Level:
#     - Playtime Left: 75s
#     - Final Coins:   2932
#     - Final Boosters: 6
# ---------------------------------------------
# --- Day 5 | Player: Average_Joe | Level Cleared: 44 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      280s
#   - State After Level:
#     - Playtime Left: 1520s
#     - Final Coins:   2520
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 5 | Player: Average_Joe | Level Cleared: 45 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      228s
#   - State After Level:
#     - Playtime Left: 1292s
#     - Final Coins:   2620
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 5 | Player: Average_Joe | Level Cleared: 46 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      290s
#   - State After Level:
#     - Playtime Left: 1002s
#     - Final Coins:   2722
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 5 | Player: Average_Joe | Level Cleared: 47 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      295s
#   - State After Level:
#     - Playtime Left: 707s
#     - Final Coins:   2826
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 5 | Player: Average_Joe | Level Cleared: 48 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      300s
#   - State After Level:
#     - Playtime Left: 407s
#     - Final Coins:   2932
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 5 | Player: Average_Joe | Level Cleared: 49 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  1
#   - Time Cost:      199s
#   - State After Level:
#     - Playtime Left: 208s
#     - Final Coins:   3040
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 5 | Player: Rich_Spender | Level Cleared: 41 ---
#   - Struggle Score: 0.23
#   - Boosters Used:  0
#   - Time Cost:      326s
#   - State After Level:
#     - Playtime Left: 1474s
#     - Final Coins:   2232
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 5 | Player: Rich_Spender | Level Cleared: 42 ---
#   - Struggle Score: 0.24
#   - Boosters Used:  0
#   - Time Cost:      334s
#   - State After Level:
#     - Playtime Left: 1140s
#     - Final Coins:   2326
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 5 | Player: Rich_Spender | Level Cleared: 43 ---
#   - Struggle Score: 0.24
#   - Boosters Used:  0
#   - Time Cost:      343s
#   - State After Level:
#     - Playtime Left: 797s
#     - Final Coins:   2422
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 5 | Player: Rich_Spender | Level Cleared: 44 ---
#   - Struggle Score: 0.25
#   - Boosters Used:  0
#   - Time Cost:      351s
#   - State After Level:
#     - Playtime Left: 446s
#     - Final Coins:   2520
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 5 | Player: Rich_Spender | Level Cleared: 45 ---
#   - Struggle Score: 0.26
#   - Boosters Used:  1
#   - Time Cost:      288s
#   - State After Level:
#     - Playtime Left: 158s
#     - Final Coins:   2620
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 6 | Player: Frugal_Expert | Level Cleared: 49 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      305s
#   - State After Level:
#     - Playtime Left: 1495s
#     - Final Coins:   3040
#     - Final Boosters: 6
# ---------------------------------------------
# --- Day 6 | Player: Frugal_Expert | Level Cleared: 50 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      310s
#   - State After Level:
#     - Playtime Left: 1185s
#     - Final Coins:   3150
#     - Final Boosters: 6
# ---------------------------------------------
# --- Day 6 | Player: Frugal_Expert | Level Cleared: 51 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      315s
#   - State After Level:
#     - Playtime Left: 870s
#     - Final Coins:   3262
#     - Final Boosters: 6
# ---------------------------------------------
# --- Day 6 | Player: Frugal_Expert | Level Cleared: 52 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      320s
#   - State After Level:
#     - Playtime Left: 550s
#     - Final Coins:   3376
#     - Final Boosters: 7
# ---------------------------------------------
# --- Day 6 | Player: Frugal_Expert | Level Cleared: 53 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      325s
#   - State After Level:
#     - Playtime Left: 225s
#     - Final Coins:   3492
#     - Final Boosters: 7
# ---------------------------------------------
# --- Day 6 | Player: Average_Joe | Level Cleared: 50 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      310s
#   - State After Level:
#     - Playtime Left: 1490s
#     - Final Coins:   3150
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 6 | Player: Average_Joe | Level Cleared: 51 ---
#   - Struggle Score: 0.01
#   - Boosters Used:  0
#   - Time Cost:      318s
#   - State After Level:
#     - Playtime Left: 1172s
#     - Final Coins:   3262
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 6 | Player: Average_Joe | Level Cleared: 52 ---
#   - Struggle Score: 0.02
#   - Boosters Used:  0
#   - Time Cost:      326s
#   - State After Level:
#     - Playtime Left: 846s
#     - Final Coins:   3376
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 6 | Player: Average_Joe | Level Cleared: 53 ---
#   - Struggle Score: 0.02
#   - Boosters Used:  0
#   - Time Cost:      333s
#   - State After Level:
#     - Playtime Left: 513s
#     - Final Coins:   3492
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 6 | Player: Average_Joe | Level Cleared: 54 ---
#   - Struggle Score: 0.03
#   - Boosters Used:  0
#   - Time Cost:      341s
#   - State After Level:
#     - Playtime Left: 172s
#     - Final Coins:   3610
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 6 | Player: Rich_Spender | Level Cleared: 46 ---
#   - Struggle Score: 0.27
#   - Boosters Used:  0
#   - Time Cost:      368s
#   - State After Level:
#     - Playtime Left: 1432s
#     - Final Coins:   2722
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 6 | Player: Rich_Spender | Level Cleared: 47 ---
#   - Struggle Score: 0.28
#   - Boosters Used:  0
#   - Time Cost:      377s
#   - State After Level:
#     - Playtime Left: 1055s
#     - Final Coins:   2826
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 6 | Player: Rich_Spender | Level Cleared: 48 ---
#   - Struggle Score: 0.28
#   - Boosters Used:  0
#   - Time Cost:      386s
#   - State After Level:
#     - Playtime Left: 669s
#     - Final Coins:   2932
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 6 | Player: Rich_Spender | Level Cleared: 49 ---
#   - Struggle Score: 0.29
#   - Boosters Used:  1
#   - Time Cost:      257s
#   - State After Level:
#     - Playtime Left: 412s
#     - Final Coins:   3040
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 6 | Player: Rich_Spender | Level Cleared: 50 ---
#   - Struggle Score: 0.30
#   - Boosters Used:  0
#   - Time Cost:      403s
#   - State After Level:
#     - Playtime Left: 9s
#     - Final Coins:   3150
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 7 | Player: Frugal_Expert | Level Cleared: 54 ---
#   - Struggle Score: 0.00
#   - Boosters Used:  0
#   - Time Cost:      330s
#   - State After Level:
#     - Playtime Left: 1470s
#     - Final Coins:   3610
#     - Final Boosters: 7
# ---------------------------------------------
# --- Day 7 | Player: Rich_Spender | Level Cleared: 51 ---
#   - Struggle Score: 0.31
#   - Boosters Used:  0
#   - Time Cost:      413s
#   - State After Level:
#     - Playtime Left: 1387s
#     - Final Coins:   3262
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 7 | Player: Rich_Spender | Level Cleared: 52 ---
#   - Struggle Score: 0.32
#   - Boosters Used:  0
#   - Time Cost:      422s
#   - State After Level:
#     - Playtime Left: 965s
#     - Final Coins:   3376
#     - Final Boosters: 1
# ---------------------------------------------
# --- Day 7 | Player: Rich_Spender | Level Cleared: 53 ---
#   - Struggle Score: 0.32
#   - Boosters Used:  1
#   - Time Cost:      345s
#   - State After Level:
#     - Playtime Left: 620s
#     - Final Coins:   3492
#     - Final Boosters: 0
# ---------------------------------------------
# --- Day 7 | Player: Rich_Spender | Level Cleared: 54 ---
#   - Struggle Score: 0.33
#   - Boosters Used:  0
#   - Time Cost:      440s
#   - State After Level:
#     - Playtime Left: 180s
#     - Final Coins:   3610
#     - Final Boosters: 0
# ---------------------------------------------

# %%
for level in level_list:
    print(f"{level.base_duration}\t{level.difficulty}")
# Out:
# 65	0.10800000000000001
# 70	0.116
# 75	0.124
# 80	0.132
# 85	0.14
# 90	0.14800000000000002
# 95	0.15600000000000003
# 100	0.164
# 105	0.172
# 110	0.18000000000000002
# 115	0.188
# 120	0.196
# 125	0.20400000000000001
# 130	0.21200000000000002
# 135	0.22
# 140	0.228
# 145	0.23600000000000002
# 150	0.244
# 155	0.252
# 160	0.26
# 165	0.268
# 170	0.276
# 175	0.28400000000000003
# 180	0.29200000000000004
# 185	0.30000000000000004
# 190	0.30800000000000005
# 195	0.31600000000000006
# 200	0.32400000000000007
# 205	0.33199999999999996
# 210	0.33999999999999997
# 215	0.348
# 220	0.356
# 225	0.364
# 230	0.372
# 235	0.38
# 240	0.388
# 245	0.396
# 250	0.404
# 255	0.41200000000000003
# 260	0.42000000000000004
# 265	0.42800000000000005
# 270	0.43600000000000005
# 275	0.44400000000000006
# 280	0.45200000000000007
# 285	0.4600000000000001
# 290	0.4680000000000001
# 295	0.476
# 300	0.484
# 305	0.492
# 310	0.5
# 315	0.508
# 320	0.516
# 325	0.524
# 330	0.532
# 335	0.54
# 340	0.548
# 345	0.5559999999999999
# 350	0.564
# 355	0.572
# 360	0.58
# 365	0.588
# 370	0.596
# 375	0.604
# 380	0.612
# 385	0.62
# 390	0.628
# 395	0.636
# 400	0.644
# 405	0.6519999999999999
# 410	0.6599999999999999
# 415	0.6679999999999999
# 420	0.6759999999999999
# 425	0.6839999999999999
# 430	0.692
# 435	0.7000000000000001
# 440	0.7080000000000001
# 445	0.7160000000000001
# 450	0.7240000000000001
# 455	0.7320000000000001
# 460	0.7400000000000001
# 465	0.7480000000000001
# 470	0.756
# 475	0.764
# 480	0.772
# 485	0.78
# 490	0.788
# 495	0.796
# 500	0.804
# 505	0.812
# 510	0.8200000000000001
# 515	0.8280000000000001
# 520	0.8360000000000001
# 525	0.8440000000000001
# 530	0.852
# 535	0.86
# 540	0.868
# 545	0.876
# 550	0.884
# 555	0.892
# 560	0.9
